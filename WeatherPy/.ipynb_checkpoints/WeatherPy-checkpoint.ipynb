# %% [markdown]
# ### Justin Boggs
# ### SMU Data Science Cohort
#
# #### This notebook creates a random list of geographical coordinates. Based on these random coordinates, weather data is pulled via API for each location and multiple charts are created based on weather-related variables.
#
# ### Observable trends
#
# #### 1. Latitude and temperature are the highest correlated datasets based on the graphs. The surprise was that the highest temperatures are slightly south of the equator when general concensus would lead us to believe that the equator would have the hottest temperatures. This is due to the earth's axis tilt. The latitude with the highest temperatures will also change based on the time of year the data is pulled.
#
# #### 2. Latitude has little to no bearing on wind speed or cloudiness. I was surprised as I thought wind speed would be greatly affected by latitude.
#
# #### 3. Humidity levels are more centralized at a higher levels the further north of the equator you travel. This does not mean there is more moisture in the air than warmer locations with a lower humidity, as the amount of moisture in the atmosphere is directly related to the temperature. Warm air can hold more moisture than cold air so the same amount of moisture will show a lower humidity in warmer climates as opposed to colder climates.

# %%
### Dependencies and Setup
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress
import json
import pprint as pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = 'output_data/cities.csv'

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding coordinates, city, and country
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
#zip coordinates together
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 618

# %%
#base url
url = 'http://api.openweathermap.org/data/2.5/weather?'
#set units to pull data
units = 'imperial'
#build partial query url
query_url = f'{url}appid={weather_api_key}&units={units}&q='

# %%
#set up lists to hold response info
city_name = []
country = []
city_id = []
lat = []
lng = []
temp = []
humidity = []
cloudiness = []
wind_speed = []

#set counter to store records
record_counter = 0
set_counter = 1

print('Beginning Data Retrieval')
print('------------------------')

#loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    #run while record counter is less than 50
    if record_counter < 50:
        #and 1 to the record counter after each loop
        record_counter += 1
    else:
        #add one to the set counter when 50 is reached
        set_counter += 1
        #set the record counter
        record_counter = 1
    #print out the record number as processing
    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))
    #loop through and save the json info for each city
    try:
        city_name.append(response['name'])
        country.append(response['sys']['country'])
        city_id.append(response['id'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
    #skip if no city name is found
    except:
        print('City not found. Skipping...')
        pass
print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')

        
#print the length of each to to ensure they all have the same number of values
#print(len(city_name))
#print(len(city_id))
#print(len(lat))
#print(len(lng))
#print(len(temp))
#print(len(humidity))
#print(len(cloudiness))
#print(len(wind_speed))
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 1 | hithadhoo
# Processing record 2 of set 1 | avarua
# Processing record 3 of set 1 | klaksvik
# Processing record 4 of set 1 | hilo
# Processing record 5 of set 1 | bandarbeyla
# Processing record 6 of set 1 | farmington
# Processing record 7 of set 1 | severnyy
# Processing record 8 of set 1 | new norfolk
# Processing record 9 of set 1 | busselton
# Processing record 10 of set 1 | butaritari
# Processing record 11 of set 1 | victoria
# Processing record 12 of set 1 | atuona
# Processing record 13 of set 1 | haibowan
# City not found. Skipping...
# Processing record 14 of set 1 | hofn
# Processing record 15 of set 1 | port alfred
# Processing record 16 of set 1 | torbay
# Processing record 17 of set 1 | mataura
# Processing record 18 of set 1 | jamestown
# Processing record 19 of set 1 | nadym
# Processing record 20 of set 1 | rikitea
# Processing record 21 of set 1 | thompson
# Processing record 22 of set 1 | bouillante
# Processing record 23 of set 1 | tuatapere
# Processing record 24 of set 1 | salvador
# Processing record 25 of set 1 | sueyoshi
# Processing record 26 of set 1 | severo-kurilsk
# Processing record 27 of set 1 | laredo
# Processing record 28 of set 1 | berzence
# Processing record 29 of set 1 | foki
# Processing record 30 of set 1 | belushya guba
# City not found. Skipping...
# Processing record 31 of set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing record 32 of set 1 | cururupu
# Processing record 33 of set 1 | vao
# Processing record 34 of set 1 | taolanaro
# City not found. Skipping...
# Processing record 35 of set 1 | punta arenas
# Processing record 36 of set 1 | belyy yar
# Processing record 37 of set 1 | oriximina
# Processing record 38 of set 1 | nikolskoye
# Processing record 39 of set 1 | jumla
# Processing record 40 of set 1 | byron bay
# Processing record 41 of set 1 | la ronge
# Processing record 42 of set 1 | umm lajj
# Processing record 43 of set 1 | puerto ayora
# Processing record 44 of set 1 | olafsvik
# Processing record 45 of set 1 | ribeira grande
# Processing record 46 of set 1 | hermanus
# Processing record 47 of set 1 | karratha
# Processing record 48 of set 1 | salalah
# Processing record 49 of set 1 | flinders
# Processing record 50 of set 1 | amderma
# City not found. Skipping...
# Processing record 1 of set 2 | tsihombe
# City not found. Skipping...
# Processing record 2 of set 2 | dolbeau
# City not found. Skipping...
# Processing record 3 of set 2 | sept-iles
# Processing record 4 of set 2 | caravelas
# Processing record 5 of set 2 | alamos
# Processing record 6 of set 2 | harper
# Processing record 7 of set 2 | tasiilaq
# Processing record 8 of set 2 | makrikapa
# City not found. Skipping...
# Processing record 9 of set 2 | port elizabeth
# Processing record 10 of set 2 | bay roberts
# Processing record 11 of set 2 | viedma
# Processing record 12 of set 2 | bethel
# Processing record 13 of set 2 | lagoa
# Processing record 14 of set 2 | codajas
# Processing record 15 of set 2 | provideniya
# Processing record 16 of set 2 | santa maria
# Processing record 17 of set 2 | cabo san lucas
# Processing record 18 of set 2 | marhaura
# Processing record 19 of set 2 | san vicente
# Processing record 20 of set 2 | whitehorse
# Processing record 21 of set 2 | albany
# Processing record 22 of set 2 | inyonga
# Processing record 23 of set 2 | rabo de peixe
# Processing record 24 of set 2 | hambantota
# Processing record 25 of set 2 | cape town
# Processing record 26 of set 2 | tayibe
# City not found. Skipping...
# Processing record 27 of set 2 | mar del plata
# Processing record 28 of set 2 | georgetown
# Processing record 29 of set 2 | culipapa
# City not found. Skipping...
# Processing record 30 of set 2 | saldanha
# Processing record 31 of set 2 | inhambane
# Processing record 32 of set 2 | sitka
# Processing record 33 of set 2 | berbera
# Processing record 34 of set 2 | yellowknife
# Processing record 35 of set 2 | codrington
# Processing record 36 of set 2 | reyes
# Processing record 37 of set 2 | ushuaia
# Processing record 38 of set 2 | east london
# Processing record 39 of set 2 | nome
# Processing record 40 of set 2 | tarko-sale
# Processing record 41 of set 2 | bluff
# Processing record 42 of set 2 | luderitz
# Processing record 43 of set 2 | mayumba
# Processing record 44 of set 2 | biggar
# Processing record 45 of set 2 | nandu
# Processing record 46 of set 2 | satitoa
# City not found. Skipping...
# Processing record 47 of set 2 | lakatoro
# Processing record 48 of set 2 | los llanos de aridane
# Processing record 49 of set 2 | palu
# Processing record 50 of set 2 | bathsheba
# Processing record 1 of set 3 | barrow
# Processing record 2 of set 3 | prainha
# Processing record 3 of set 3 | nirmali
# Processing record 4 of set 3 | khorixas
# Processing record 5 of set 3 | hobart
# Processing record 6 of set 3 | barawe
# City not found. Skipping...
# Processing record 7 of set 3 | khatanga
# Processing record 8 of set 3 | arraial do cabo
# Processing record 9 of set 3 | cidreira
# Processing record 10 of set 3 | mahebourg
# Processing record 11 of set 3 | ambilobe
# Processing record 12 of set 3 | urdoma
# Processing record 13 of set 3 | ilulissat
# Processing record 14 of set 3 | malwan
# City not found. Skipping...
# Processing record 15 of set 3 | vaitupu
# City not found. Skipping...
# Processing record 16 of set 3 | saint-philippe
# Processing record 17 of set 3 | opuwo
# Processing record 18 of set 3 | hirara
# Processing record 19 of set 3 | yeroham
# Processing record 20 of set 3 | scottsburgh
# City not found. Skipping...
# Processing record 21 of set 3 | colesberg
# Processing record 22 of set 3 | bredasdorp
# Processing record 23 of set 3 | shingu
# Processing record 24 of set 3 | malanville
# Processing record 25 of set 3 | muroto
# Processing record 26 of set 3 | samusu
# City not found. Skipping...
# Processing record 27 of set 3 | salamanca
# Processing record 28 of set 3 | kapaa
# Processing record 29 of set 3 | tarudant
# City not found. Skipping...
# Processing record 30 of set 3 | mbeya
# Processing record 31 of set 3 | kununurra
# Processing record 32 of set 3 | upernavik
# Processing record 33 of set 3 | kot kapura
# Processing record 34 of set 3 | guerrero negro
# Processing record 35 of set 3 | aklavik
# Processing record 36 of set 3 | castro
# Processing record 37 of set 3 | naze
# Processing record 38 of set 3 | pombia
# Processing record 39 of set 3 | urucara
# Processing record 40 of set 3 | rolim de moura
# City not found. Skipping...
# Processing record 41 of set 3 | gondanglegi
# Processing record 42 of set 3 | hallingby
# City not found. Skipping...
# Processing record 43 of set 3 | sabang
# Processing record 44 of set 3 | cherskiy
# Processing record 45 of set 3 | vaini
# Processing record 46 of set 3 | ust-nera
# Processing record 47 of set 3 | barbar
# City not found. Skipping...
# Processing record 48 of set 3 | inuvik
# Processing record 49 of set 3 | antofagasta
# Processing record 50 of set 3 | haimen
# Processing record 1 of set 4 | jiangyou
# Processing record 2 of set 4 | nouadhibou
# Processing record 3 of set 4 | salima
# Processing record 4 of set 4 | abu zabad
# Processing record 5 of set 4 | lahuachaca
# Processing record 6 of set 4 | xinxiang
# Processing record 7 of set 4 | kidal
# Processing record 8 of set 4 | carnarvon
# Processing record 9 of set 4 | sao filipe
# Processing record 10 of set 4 | abapo
# Processing record 11 of set 4 | stokmarknes
# Processing record 12 of set 4 | saint george
# Processing record 13 of set 4 | sao mateus do maranhao
# Processing record 14 of set 4 | lolua
# City not found. Skipping...
# Processing record 15 of set 4 | vaitape
# Processing record 16 of set 4 | tabiauea
# City not found. Skipping...
# Processing record 17 of set 4 | porosozero
# Processing record 18 of set 4 | ponta do sol
# Processing record 19 of set 4 | saskylakh
# Processing record 20 of set 4 | norman wells
# Processing record 21 of set 4 | hamilton
# Processing record 22 of set 4 | qaanaaq
# Processing record 23 of set 4 | longyearbyen
# Processing record 24 of set 4 | rawson
# Processing record 25 of set 4 | afmadu
# City not found. Skipping...
# Processing record 26 of set 4 | poum
# Processing record 27 of set 4 | tiksi
# Processing record 28 of set 4 | trincomalee
# Processing record 29 of set 4 | nanortalik
# Processing record 30 of set 4 | salym
# Processing record 31 of set 4 | kaitangata
# Processing record 32 of set 4 | palabuhanratu
# City not found. Skipping...
# Processing record 33 of set 4 | altus
# Processing record 34 of set 4 | araouane
# Processing record 35 of set 4 | pisco
# Processing record 36 of set 4 | nizwa
# Processing record 37 of set 4 | chapais
# Processing record 38 of set 4 | bengkulu
# Processing record 39 of set 4 | zlobin
# Processing record 40 of set 4 | faanui
# Processing record 41 of set 4 | half moon bay
# Processing record 42 of set 4 | lebu
# Processing record 43 of set 4 | bukama
# Processing record 44 of set 4 | chuy
# Processing record 45 of set 4 | merauke
# Processing record 46 of set 4 | rocha
# Processing record 47 of set 4 | urubicha
# Processing record 48 of set 4 | lavrentiya
# Processing record 49 of set 4 | komsomolskiy
# Processing record 50 of set 4 | townsville
# Processing record 1 of set 5 | petropavlovsk-kamchatskiy
# Processing record 2 of set 5 | husavik
# Processing record 3 of set 5 | hanmer springs
# Processing record 4 of set 5 | kavieng
# Processing record 5 of set 5 | selma
# Processing record 6 of set 5 | mapastepec
# Processing record 7 of set 5 | takoradi
# Processing record 8 of set 5 | kalmunai
# Processing record 9 of set 5 | khash
# Processing record 10 of set 5 | kawalu
# Processing record 11 of set 5 | bud
# Processing record 12 of set 5 | benguela
# Processing record 13 of set 5 | chifeng
# Processing record 14 of set 5 | tura
# Processing record 15 of set 5 | alta floresta
# Processing record 16 of set 5 | mnogovershinnyy
# Processing record 17 of set 5 | galiwinku
# City not found. Skipping...
# Processing record 18 of set 5 | san ramon
# Processing record 19 of set 5 | ketchikan
# Processing record 20 of set 5 | asau
# Processing record 21 of set 5 | ocampo
# Processing record 22 of set 5 | talnakh
# Processing record 23 of set 5 | karamay
# City not found. Skipping...
# Processing record 24 of set 5 | vardo
# Processing record 25 of set 5 | ixtapa
# Processing record 26 of set 5 | saint-louis
# Processing record 27 of set 5 | chokurdakh
# Processing record 28 of set 5 | madera
# Processing record 29 of set 5 | teya
# Processing record 30 of set 5 | tyret pervaya
# Processing record 31 of set 5 | manzhouli
# Processing record 32 of set 5 | bagdarin
# Processing record 33 of set 5 | vozhega
# Processing record 34 of set 5 | waingapu
# Processing record 35 of set 5 | veraval
# Processing record 36 of set 5 | mayna
# Processing record 37 of set 5 | fortuna
# Processing record 38 of set 5 | fort thomas
# Processing record 39 of set 5 | saint anthony
# Processing record 40 of set 5 | progreso
# Processing record 41 of set 5 | chaman
# Processing record 42 of set 5 | alibag
# Processing record 43 of set 5 | chor
# Processing record 44 of set 5 | riyadh
# Processing record 45 of set 5 | esperance
# Processing record 46 of set 5 | yamada
# Processing record 47 of set 5 | attawapiskat
# City not found. Skipping...
# Processing record 48 of set 5 | grand-santi
# Processing record 49 of set 5 | bandundu
# Processing record 50 of set 5 | usevya
# Processing record 1 of set 6 | samarai
# Processing record 2 of set 6 | mount gambier
# Processing record 3 of set 6 | kodiak
# Processing record 4 of set 6 | ust-kachka
# Processing record 5 of set 6 | coahuayana
# Processing record 6 of set 6 | jardim
# Processing record 7 of set 6 | tumannyy
# City not found. Skipping...
# Processing record 8 of set 6 | sao felix do xingu
# Processing record 9 of set 6 | marcona
# City not found. Skipping...
# Processing record 10 of set 6 | louisbourg
# City not found. Skipping...
# Processing record 11 of set 6 | belaya gora
# Processing record 12 of set 6 | santa isabel do rio negro
# Processing record 13 of set 6 | san patricio
# Processing record 14 of set 6 | clyde river
# Processing record 15 of set 6 | lewistown
# Processing record 16 of set 6 | tadine
# Processing record 17 of set 6 | ouesso
# Processing record 18 of set 6 | dikson
# Processing record 19 of set 6 | grand river south east
# City not found. Skipping...
# Processing record 20 of set 6 | vestmannaeyjar
# Processing record 21 of set 6 | aransas pass
# Processing record 22 of set 6 | oistins
# Processing record 23 of set 6 | katsuura
# Processing record 24 of set 6 | port lincoln
# Processing record 25 of set 6 | russell
# Processing record 26 of set 6 | asfi
# Processing record 27 of set 6 | broken hill
# Processing record 28 of set 6 | hami
# Processing record 29 of set 6 | guarapari
# Processing record 30 of set 6 | richards bay
# Processing record 31 of set 6 | el alto
# Processing record 32 of set 6 | sambava
# Processing record 33 of set 6 | muros
# Processing record 34 of set 6 | vila velha
# Processing record 35 of set 6 | jiddah
# City not found. Skipping...
# Processing record 36 of set 6 | leningradskiy
# Processing record 37 of set 6 | skibbereen
# Processing record 38 of set 6 | pierre
# Processing record 39 of set 6 | nuristan
# Processing record 40 of set 6 | seoul
# Processing record 41 of set 6 | kushmurun
# Processing record 42 of set 6 | fairbanks
# Processing record 43 of set 6 | ranong
# Processing record 44 of set 6 | dobris
# Processing record 45 of set 6 | alindao
# Processing record 46 of set 6 | ocos
# Processing record 47 of set 6 | mecca
# Processing record 48 of set 6 | diban
# Processing record 49 of set 6 | bilibino
# Processing record 50 of set 6 | tuktoyaktuk
# Processing record 1 of set 7 | lorengau
# Processing record 2 of set 7 | omboue
# Processing record 3 of set 7 | erenhot
# Processing record 4 of set 7 | solano
# Processing record 5 of set 7 | isangel
# Processing record 6 of set 7 | crewe
# Processing record 7 of set 7 | chepareria
# Processing record 8 of set 7 | saint-pierre
# Processing record 9 of set 7 | atar
# Processing record 10 of set 7 | batticaloa
# Processing record 11 of set 7 | praia da vitoria
# Processing record 12 of set 7 | parrita
# Processing record 13 of set 7 | bajah
# Processing record 14 of set 7 | henties bay
# Processing record 15 of set 7 | stornoway
# Processing record 16 of set 7 | sinkat
# City not found. Skipping...
# Processing record 17 of set 7 | pochutla
# Processing record 18 of set 7 | oranjemund
# Processing record 19 of set 7 | tigil
# Processing record 20 of set 7 | onalaska
# Processing record 21 of set 7 | dickinson
# Processing record 22 of set 7 | danielskuil
# Processing record 23 of set 7 | lixourion
# Processing record 24 of set 7 | menongue
# Processing record 25 of set 7 | pevek
# Processing record 26 of set 7 | dingle
# Processing record 27 of set 7 | disna
# Processing record 28 of set 7 | vanimo
# Processing record 29 of set 7 | berlevag
# Processing record 30 of set 7 | cruden bay
# City not found. Skipping...
# Processing record 31 of set 7 | macaboboni
# City not found. Skipping...
# Processing record 32 of set 7 | inta
# Processing record 33 of set 7 | kodino
# Processing record 34 of set 7 | cabra
# Processing record 35 of set 7 | kavaratti
# Processing record 36 of set 7 | vostok
# Processing record 37 of set 7 | burnie
# Processing record 38 of set 7 | manzanillo
# Processing record 39 of set 7 | narsaq
# Processing record 40 of set 7 | lucapa
# Processing record 41 of set 7 | coroico
# Processing record 42 of set 7 | umzimvubu
# City not found. Skipping...
# Processing record 43 of set 7 | amethi
# Processing record 44 of set 7 | namatanai
# Processing record 45 of set 7 | padang
# Processing record 46 of set 7 | birjand
# Processing record 47 of set 7 | palmer
# Processing record 48 of set 7 | verkhnevilyuysk
# Processing record 49 of set 7 | polunochnoye
# Processing record 50 of set 7 | urdzhar
# City not found. Skipping...
# Processing record 1 of set 8 | pontes e lacerda
# Processing record 2 of set 8 | lucea
# Processing record 3 of set 8 | guerrero
# Processing record 4 of set 8 | ust-kulom
# Processing record 5 of set 8 | adrar
# Processing record 6 of set 8 | amapa
# Processing record 7 of set 8 | sosnovo-ozerskoye
# Processing record 8 of set 8 | maarianhamina
# Processing record 9 of set 8 | matay
# Processing record 10 of set 8 | zhigansk
# Processing record 11 of set 8 | tidore
# City not found. Skipping...
# Processing record 12 of set 8 | dumas
# Processing record 13 of set 8 | kralendijk
# Processing record 14 of set 8 | lompoc
# Processing record 15 of set 8 | udimskiy
# Processing record 16 of set 8 | majene
# Processing record 17 of set 8 | barentsburg
# City not found. Skipping...
# Processing record 18 of set 8 | buluang
# Processing record 19 of set 8 | meridian
# Processing record 20 of set 8 | marsa matruh
# Processing record 21 of set 8 | gonbad-e qabus
# Processing record 22 of set 8 | ninghai
# Processing record 23 of set 8 | wanning
# Processing record 24 of set 8 | ostrovnoy
# Processing record 25 of set 8 | opunake
# Processing record 26 of set 8 | iki-burul
# Processing record 27 of set 8 | mondovi
# Processing record 28 of set 8 | bubaque
# Processing record 29 of set 8 | pangnirtung
# Processing record 30 of set 8 | burica
# City not found. Skipping...
# Processing record 31 of set 8 | aberdeen
# Processing record 32 of set 8 | ulladulla
# Processing record 33 of set 8 | ukiah
# Processing record 34 of set 8 | cabedelo
# Processing record 35 of set 8 | buon me thuot
# City not found. Skipping...
# Processing record 36 of set 8 | furukawa
# Processing record 37 of set 8 | shipunovo
# Processing record 38 of set 8 | mergui
# City not found. Skipping...
# Processing record 39 of set 8 | loding
# Processing record 40 of set 8 | ust-ilimsk
# Processing record 41 of set 8 | nkongsamba
# Processing record 42 of set 8 | pakala
# Processing record 43 of set 8 | piney green
# Processing record 44 of set 8 | san quintin
# Processing record 45 of set 8 | dunedin
# Processing record 46 of set 8 | kulhudhuffushi
# Processing record 47 of set 8 | havre-saint-pierre
# Processing record 48 of set 8 | karauzyak
# City not found. Skipping...
# Processing record 49 of set 8 | malanje
# Processing record 50 of set 8 | ksenyevka
# City not found. Skipping...
# Processing record 1 of set 9 | kruisfontein
# Processing record 2 of set 9 | baherden
# Processing record 3 of set 9 | arlit
# Processing record 4 of set 9 | flin flon
# Processing record 5 of set 9 | atyrau
# Processing record 6 of set 9 | san cristobal
# Processing record 7 of set 9 | ambulu
# Processing record 8 of set 9 | lasa
# Processing record 9 of set 9 | grindavik
# Processing record 10 of set 9 | liancheng
# Processing record 11 of set 9 | kahului
# Processing record 12 of set 9 | rio grande
# Processing record 13 of set 9 | powell river
# Processing record 14 of set 9 | zhezkazgan
# Processing record 15 of set 9 | auki
# Processing record 16 of set 9 | mys shmidta
# City not found. Skipping...
# Processing record 17 of set 9 | madang
# Processing record 18 of set 9 | isla mujeres
# Processing record 19 of set 9 | westport
# Processing record 20 of set 9 | laguna
# Processing record 21 of set 9 | vila franca do campo
# Processing record 22 of set 9 | geraldton
# Processing record 23 of set 9 | kieta
# Processing record 24 of set 9 | taganak
# Processing record 25 of set 9 | nsanje
# Processing record 26 of set 9 | axim
# Processing record 27 of set 9 | palora
# Processing record 28 of set 9 | margate
# Processing record 29 of set 9 | akyab
# Processing record 30 of set 9 | coihaique
# Processing record 31 of set 9 | lebedinyy
# Processing record 32 of set 9 | kibre mengist
# Processing record 33 of set 9 | barinas
# Processing record 34 of set 9 | lakes entrance
# Processing record 35 of set 9 | pitimbu
# Processing record 36 of set 9 | ushtobe
# Processing record 37 of set 9 | wulanhaote
# City not found. Skipping...
# Processing record 38 of set 9 | narasannapeta
# Processing record 39 of set 9 | awbari
# Processing record 40 of set 9 | iberia
# Processing record 41 of set 9 | champerico
# Processing record 42 of set 9 | morena
# Processing record 43 of set 9 | finschhafen
# Processing record 44 of set 9 | dubti
# Processing record 45 of set 9 | skjervoy
# Processing record 46 of set 9 | shushtar
# Processing record 47 of set 9 | portland
# Processing record 48 of set 9 | mocuba
# Processing record 49 of set 9 | ibra
# Processing record 50 of set 9 | poronaysk
# Processing record 1 of set 10 | george
# Processing record 2 of set 10 | naberera
# Processing record 3 of set 10 | port hedland
# Processing record 4 of set 10 | aswan
# Processing record 5 of set 10 | bambous virieux
# Processing record 6 of set 10 | maseru
# Processing record 7 of set 10 | yulara
# Processing record 8 of set 10 | tommot
# Processing record 9 of set 10 | souillac
# Processing record 10 of set 10 | puerto quijarro
# Processing record 11 of set 10 | srivardhan
# Processing record 12 of set 10 | fairview
# Processing record 13 of set 10 | vestmanna
# Processing record 14 of set 10 | dordrecht
# Processing record 15 of set 10 | felidhoo
# City not found. Skipping...
# Processing record 16 of set 10 | zharkent
# Processing record 17 of set 10 | mazyr
# Processing record 18 of set 10 | fort nelson
# Processing record 19 of set 10 | weinan
# Processing record 20 of set 10 | orocue
# Processing record 21 of set 10 | havoysund
# Processing record 22 of set 10 | innisfail
# Processing record 23 of set 10 | kabanjahe
# Processing record 24 of set 10 | montivilliers
# Processing record 25 of set 10 | kimbe
# Processing record 26 of set 10 | northampton
# Processing record 27 of set 10 | cayenne
# Processing record 28 of set 10 | lulea
# Processing record 29 of set 10 | anadyr
# Processing record 30 of set 10 | sicuani
# Processing record 31 of set 10 | vanderhoof
# Processing record 32 of set 10 | pedernales
# Processing record 33 of set 10 | nordhausen
# Processing record 34 of set 10 | mayo
# Processing record 35 of set 10 | blagoyevo
# Processing record 36 of set 10 | francisco sa
# Processing record 37 of set 10 | halalo
# City not found. Skipping...
# Processing record 38 of set 10 | kanalia
# Processing record 39 of set 10 | haines junction
# Processing record 40 of set 10 | iqaluit
# Processing record 41 of set 10 | sao joao da barra
# Processing record 42 of set 10 | pavilosta
# Processing record 43 of set 10 | mao
# Processing record 44 of set 10 | gat
# Processing record 45 of set 10 | nhulunbuy
# Processing record 46 of set 10 | beringovskiy
# Processing record 47 of set 10 | guajara-mirim
# City not found. Skipping...
# Processing record 48 of set 10 | marktheidenfeld
# Processing record 49 of set 10 | pacific grove
# Processing record 50 of set 10 | tres lagoas
# Processing record 1 of set 11 | lerwick
# Processing record 2 of set 11 | victor harbor
# Processing record 3 of set 11 | lodwar
# Processing record 4 of set 11 | bairiki
# Processing record 5 of set 11 | rincon
# Processing record 6 of set 11 | lahij
# Processing record 7 of set 11 | kamenskoye
# City not found. Skipping...
# Processing record 8 of set 11 | pemberton
# Processing record 9 of set 11 | ramasukha
# City not found. Skipping...
# Processing record 10 of set 11 | tambopata
# Processing record 11 of set 11 | turan
# Processing record 12 of set 11 | iquitos
# Processing record 13 of set 11 | hasaki
# Processing record 14 of set 11 | saleaula
# City not found. Skipping...
# Processing record 15 of set 11 | itamarandiba
# Processing record 16 of set 11 | amahai
# Processing record 17 of set 11 | vitim
# Processing record 18 of set 11 | mwinilunga
# Processing record 19 of set 11 | praia
# Processing record 20 of set 11 | quatre cocos
# Processing record 21 of set 11 | gasa
# Processing record 22 of set 11 | sokol
# Processing record 23 of set 11 | salekhard
# Processing record 24 of set 11 | sinjar
# Processing record 25 of set 11 | te anau
# Processing record 26 of set 11 | biak
# Processing record 27 of set 11 | grand gaube
# Processing record 28 of set 11 | katha
# City not found. Skipping...
# Processing record 29 of set 11 | luwingu
# Processing record 30 of set 11 | shahr-e babak
# Processing record 31 of set 11 | carman
# Processing record 32 of set 11 | paciran
# Processing record 33 of set 11 | effium
# Processing record 34 of set 11 | grand centre
# City not found. Skipping...
# Processing record 35 of set 11 | pingdingshan
# Processing record 36 of set 11 | evensk
# Processing record 37 of set 11 | tabas
# Processing record 38 of set 11 | nizhneyansk
# City not found. Skipping...
# Processing record 39 of set 11 | srednekolymsk
# Processing record 40 of set 11 | auch
# Processing record 41 of set 11 | nishihara
# Processing record 42 of set 11 | sentyabrskiy
# City not found. Skipping...
# Processing record 43 of set 11 | malatya
# Processing record 44 of set 11 | oktyabrskiy
# Processing record 45 of set 11 | udachnyy
# Processing record 46 of set 11 | ahipara
# Processing record 47 of set 11 | korla
# Processing record 48 of set 11 | rayagada
# Processing record 49 of set 11 | qasigiannguit
# Processing record 50 of set 11 | batagay
# Processing record 1 of set 12 | ossora
# Processing record 2 of set 12 | ribas do rio pardo
# Processing record 3 of set 12 | jinchengjiang
# City not found. Skipping...
# Processing record 4 of set 12 | jurbise
# Processing record 5 of set 12 | kjollefjord
# Processing record 6 of set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing record 7 of set 12 | fare
# Processing record 8 of set 12 | gladstone
# Processing record 9 of set 12 | tecoanapa
# Processing record 10 of set 12 | moron
# Processing record 11 of set 12 | brawley
# Processing record 12 of set 12 | najran
# Processing record 13 of set 12 | ulety
# Processing record 14 of set 12 | mendi
# Processing record 15 of set 12 | gwadar
# Processing record 16 of set 12 | mackay
# Processing record 17 of set 12 | comodoro rivadavia
# Processing record 18 of set 12 | yanchukan
# City not found. Skipping...
# Processing record 19 of set 12 | kaseda
# Processing record 20 of set 12 | belem
# Processing record 21 of set 12 | camacha
# Processing record 22 of set 12 | shache
# Processing record 23 of set 12 | puerto del rosario
# Processing record 24 of set 12 | katangli
# Processing record 25 of set 12 | council bluffs
# Processing record 26 of set 12 | turayf
# Processing record 27 of set 12 | coos bay
# Processing record 28 of set 12 | beruwala
# Processing record 29 of set 12 | tanout
# Processing record 30 of set 12 | uaua
# Processing record 31 of set 12 | kamenka
# Processing record 32 of set 12 | eldikan
# City not found. Skipping...
# Processing record 33 of set 12 | virginia beach
# Processing record 34 of set 12 | nabire
# Processing record 35 of set 12 | west monroe
# Processing record 36 of set 12 | itaqui
# Processing record 37 of set 12 | tezu
# Processing record 38 of set 12 | whitianga
# Processing record 39 of set 12 | airai
# Processing record 40 of set 12 | craig
# Processing record 41 of set 12 | ilhabela
# Processing record 42 of set 12 | christchurch
# Processing record 43 of set 12 | yatou
# Processing record 44 of set 12 | hendek
# Processing record 45 of set 12 | alofi
# Processing record 46 of set 12 | vila do maio
# Processing record 47 of set 12 | laives
# Processing record 48 of set 12 | mackenzie
# Processing record 49 of set 12 | karaul
# City not found. Skipping...
# Processing record 50 of set 12 | skagastrond
# City not found. Skipping...
# Processing record 1 of set 13 | tirlyanskiy
# Processing record 2 of set 13 | launceston
# Processing record 3 of set 13 | primo tapia
# Processing record 4 of set 13 | kerteh
# City not found. Skipping...
# Processing record 5 of set 13 | aksu
# Processing record 6 of set 13 | tres picos
# Processing record 7 of set 13 | gambela
# Processing record 8 of set 13 | ngara
# Processing record 9 of set 13 | yumen
# Processing record 10 of set 13 | eyemouth
# Processing record 11 of set 13 | casablanca
# Processing record 12 of set 13 | shimoda
# Processing record 13 of set 13 | hualmay
# Processing record 14 of set 13 | constitucion
# Processing record 15 of set 13 | marystown
# Processing record 16 of set 13 | bossangoa
# Processing record 17 of set 13 | kangaatsiaq
# Processing record 18 of set 13 | mponela
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
#print length of city name to ensure you have enough individual cities
print(len(city_name))
# Out:
# 555

# %%
#create dataframe from the data pulled above
weather_dict = {
    'city': city_name,
    'country': country,
    'id': city_id,
    'lat': lat,
    'lng': lng,
    'temp': temp,
    'humidity': humidity,
    'clouds': cloudiness,
    'wind_speed': wind_speed
}    
weather_data = pd.DataFrame(weather_dict)
#save the city data to csv file
weather_data.to_csv(output_data_file, index=False)

# %%
#pull individual column data for scatter plots
lat_values = weather_data['lat']
temp_values = weather_data['temp']
humidity_values = weather_data['humidity']
clouds_values = weather_data['clouds']
wind_speed_values = weather_data['wind_speed']

# %% [markdown]
# # Scatter Plots

# %%
#latitude vs temperature
plt.scatter(lat_values, temp_values, marker='o', facecolors='grey', edgecolors='black')
plt.title('Latitude vs Temperature')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
#save the plot to an image file
plt.savefig('output_data/lat_temp_plt.png')

# %% [markdown]
# #### The above plot shows the relationship between temperature and latitude of the selected cities. There is a slight decrease in temperature as cities lie further south of the equator and a much large decrease in temperature the further cities are north of the equator.

# %%
#latitude vs humidity
plt.scatter(lat_values, humidity_values, marker='o', facecolors='grey', edgecolors='black')
plt.title('Latitude vs Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('output_data/lat_hum_plt.png')

# %% [markdown]
# #### The above plot compares humidity and latitude of the selected cities. Cities south of the equator tend to have a higher humidity while cities north of the equator tend to be more varied.

# %%
#latitude vs cloudiness
plt.scatter(lat_values, clouds_values, marker='o', facecolors='grey', edgecolors='black')
plt.title('Latitude vs Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('output_data/lat_cloud_plt.png')

# %% [markdown]
# #### The above plot compares cloudiness and latitude of the selected cities. It seems to be a large number of cities have either 0 or 100 percent cloudiness. It is hard to gather much information from this chart. The cloudiness metric could be difficult to measure or unreliable.

# %%
#latitude vs wind speed
plt.scatter(lat_values, wind_speed_values, marker='o', facecolors='grey', edgecolors='black')
plt.title('Latitude vs Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('output_data/lat_wind_plt.png')

# %% [markdown]
# #### The above plot compares wind speed and latitude of the selected cities. There is a small net increase in wind speed in cities north of the equator, but as you can see, most cities are under the 20 mph wind speed mark.

# %% [markdown]
# # Hemispheric Scatter Plots

# %%
#locate the data with a latitude value equal to or greater than 0 for northern hemisphere
north_hem = weather_data.loc[weather_data['lat'] >= 0]
#locate the data with a latitude value less than 0 for southern hemisphere
south_hem = weather_data.loc[weather_data['lat'] < 0]

# %%
#pull individual column data for scatter plots based on hemisphere
north_temp = north_hem['temp']
south_temp = south_hem['temp']
north_lat = north_hem['lat']
south_lat = south_hem['lat']
north_humid = north_hem['humidity']
south_humid = south_hem['humidity']
north_clouds = north_hem['clouds']
south_clouds = south_hem['clouds']
north_wind = north_hem['wind_speed']
south_wind = south_hem['wind_speed']

# %%
#northern hemisphere latitude vs temp
#create scatter plot and add the linear regression equation and line to the plot
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_lat, north_temp)
regress_values = north_lat * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
plt.scatter(north_lat, north_temp, marker='o', facecolors='grey', edgecolors='black')
plt.plot(north_lat, regress_values, 'r-')
plt.annotate(line_eq,(6,10), fontsize=10, color='red')
plt.title('Northern Hemisphere Latitude vs Temperature')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
#print out the r-squared value along with the plot
print(f'The r-squared is: {rvalue}')
#save the plot to an image file
plt.savefig('output_data/01_north_lat_temp.png')
# Out:
# The r-squared is: -0.8626259176786786

# %% [markdown]
# #### Temperature decreases as locations get further north of the equator. There is a very strong correltion between latitude and temperature in this graph.

# %%
#southern hemisphere latitude vs temp
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_lat, south_temp)
regress_values = south_lat * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
plt.scatter(south_lat, south_temp, marker='o', facecolors='#139dd2', edgecolors='black')
plt.plot(south_lat, regress_values, 'r-')
plt.annotate(line_eq,(-55,90), fontsize=10, color='red')
plt.title('Southern Hemisphere Latitude vs Temperature')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
print(f'The r-squared is: {rvalue}')
plt.savefig('output_data/01_south_lat_temp.png')
# Out:
# The r-squared is: 0.3500565975246778

# %% [markdown]
# #### Temperature decreases as locations get further south of the equator. The correlation is not as strong as it is for the northern hemisphere, but lower temperatures further from the equator is geneerally what we would expect.

# %%
#northern hemisphere lat vs humidity
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_lat, north_humid)
regress_values = north_lat * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
plt.scatter(north_lat, north_humid, marker='o', facecolors='grey', edgecolors='black')
plt.plot(north_lat, regress_values, 'r-')
plt.annotate(line_eq,(50,20), fontsize=10, color='red')
plt.title('Northern Hemisphere Latitude vs Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f'The r-squared is: {rvalue}')
plt.savefig('output_data/02_north_lat_humid.png')
# Out:
# The r-squared is: 0.3744392729729907

# %% [markdown]
# #### Humidity levels are more centralized further north of the equator and vary more closer to the equator. The correlation between humidity and latitude is weak.

# %%
#sorthern hemisphere lat vs humidity
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_lat, south_humid)
regress_values = south_lat * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
plt.scatter(south_lat, south_humid, marker='o', facecolors='#139dd2', edgecolors='black')
plt.plot(south_lat, regress_values, 'r-')
plt.annotate(line_eq,(-20,10), fontsize=10, color='red')
plt.title('Southern Hemisphere Latitude vs Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f'The r-squared is: {rvalue}')
plt.savefig('output_data/02_south_lat_humid.png')
# Out:
# The r-squared is: 0.29065833144117875

# %% [markdown]
# #### Correlation between humidity and latitude is weak for this data as well. Humidity levels tend to be more centralized closer to the equator and more varied the further south the locations get. This is the opposite of the trend we see in the northern hemisphere.

# %%
#northern hemisphere lat vs cloudiness
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_lat, north_clouds)
regress_values = north_lat * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
plt.scatter(north_lat, north_clouds, marker='o', facecolors='grey', edgecolors='black')
plt.plot(north_lat, regress_values, 'r-')
plt.annotate(line_eq,(50,50), fontsize=10, color='red')
plt.title('Northern Hemisphere Latitude vs Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f'The r-squared is: {rvalue}')
plt.savefig('output_data/03_north_lat_cloud.png')
# Out:
# The r-squared is: 0.2415865571070906

# %% [markdown]
# #### Cloudiness does not seem to correlate with latitude in the northern hemisphere. As we saw with the overall graph above, a lot of locations are listed either at 0 or 100%, and the rest are scattered throughout the other cloudiness levels.

# %%
#southern hemisphere lat vs cloudiness
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_lat, south_clouds)
regress_values = south_lat * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
plt.scatter(south_lat, south_clouds, marker='o', facecolors='#139dd2', edgecolors='black')
plt.plot(south_lat, regress_values, 'r-')
plt.annotate(line_eq,(-55,60), fontsize=10, color='red')
plt.title('Southern Hemisphere Latitude vs Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f'The r-squared is: {rvalue}')
plt.savefig('output_data/03_south_lat_cloud.png')
# Out:
# The r-squared is: 0.18181337296655348

# %% [markdown]
# #### Again, cloudiness does not correlate well with latitude in the southern hemisphere. Many locations at 0 or 100 again with the rest scattered throughout.

# %%
#northern hemisphere lat vs wind speed
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_lat, north_wind)
regress_values = north_lat * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
plt.scatter(north_lat, north_wind, marker='o', facecolors='grey', edgecolors='black')
plt.plot(north_lat, regress_values, 'r-')
plt.annotate(line_eq,(0,40), fontsize=10, color='red')
plt.title('Northern Hemisphere Latitude vs Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f'The r-squared is: {rvalue}')
plt.savefig('output_data/04_north_lat_wind.png')
# Out:
# The r-squared is: 0.26944383274135464

# %% [markdown]
# #### Wind speed is more centralized closer to the equator, but most locations have a wind speed under 20 mph so the variance is not great.

# %%
#southern hemisphere lat vs wind speed
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_lat, south_wind)
regress_values = south_lat * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
plt.scatter(south_lat, south_wind, marker='o', facecolors='#139dd2', edgecolors='black')
plt.plot(south_lat, regress_values, 'r-')
plt.annotate(line_eq,(-55,27), fontsize=10, color='red')
plt.title('Southern Hemisphere Latitude vs Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f'The r-squared is: {rvalue}')
plt.savefig('output_data/04_south_lat_wind.png')
# Out:
# The r-squared is: -0.31183526456667776

# %% [markdown]
# #### Again, wind speed is slightly more centralized closer to the equator. And again, the variance is low with only one location having a wind speed above 30 mph.
